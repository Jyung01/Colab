# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

#인증키 입력
api_key = '617a494771776c6435324e48654376'

#url 입력
url = 'http://openAPI.seoul.go.kr:8088/{0}/xml/ChunmanFreeSuggestions/1/5'. format(api_key)
print(url)
params = {
    "type": "xml",
}

response = requests.get(url, params=params)
root = ET.fromstring(response.content)

data = []
for row in root.iter("ChunmanFreeSuggestions"):
    item = {}
    item["제안번호"] = row.findtext("SN")
    item["제안제목"] = row.findtext("TITLE")
    item["제안내용"] = row.findtext("CONTENT")
    item["득표"] = row.findtext("VOTE_SCORE")
    item["제안등록일자"] = row.findtext("REG_DATE")
    data.append(item)

# Convert the list of dictionaries to a pandas DataFrame
df = pd.DataFrame(data)
print(df)

# Save the DataFrame as a CSV file
#df.to_csv("민주주의.csv", index=False)
# Out:
# http://openAPI.seoul.go.kr:8088/617a494771776c6435324e48654376/xml/ChunmanFreeSuggestions/1/5
#    제안번호  제안제목  제안내용    득표 제안등록일자
# 0  None  None  None  None   None
